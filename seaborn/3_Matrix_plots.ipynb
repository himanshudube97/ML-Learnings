# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')

flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## HEATMAP
##In order for a heatmap to work properly, your data should already be in a matrix form, the sns.heatmap function basically just colors it in for you. For example:

# %% [markdown]
# What is Correlation?
# Correlation measures the relationship between two variables.
# Positive Correlation (closer to +1): When one variable increases, the other also increases.
# Negative Correlation (closer to -1): When one variable increases, the other decreases.
# No Correlation (around 0): No clear relationship between the two variables.
# For example:
#
# Height and weight may have a positive correlation (taller people often weigh more).
# Exercise and body fat may have a negative correlation (more exercise, less fat).
# Correlation Matrix
# A correlation matrix is a table showing the correlation between all pairs of variables in your dataset.
# It’s a grid where:
# Rows and columns represent variables.
# Each cell contains the correlation value between two variables.
# Values range from -1 (strong negative) to +1 (strong positive).
# Example:
#
# Height	Weight	Age
# Height	1.0	0.8	0.1
# Weight	0.8	1.0	0.2
# Age	0.1	0.2	1.0
# Diagonal cells (1.0): These are always 1.0 because a variable is perfectly correlated with itself.
# Off-diagonal cells: Show correlations between different variables

# %%
# Matrix form for correlation data
data_1 = tips.corr(numeric_only=True)
data_1
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data_1,annot=True)
plt.show()

# %%
## rearranging flights data
fp = flights.pivot_table(values='passengers',index='month',columns='year', observed=False)
fp
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(fp, cmap="coolwarm", linewidths=1)
plt.show()

# %%
#### CLUSTER MAP

# %%
sns.clustermap(fp, cmap = "coolwarm")
plt.show()
